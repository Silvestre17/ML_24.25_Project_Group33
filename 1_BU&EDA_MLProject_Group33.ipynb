# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTaJWG7PzF3toxaRMB1-JicpqMgJuEXATd0fg&" style="width: 180px;margin-top:50px;margin-bottom:50px;" align="left">
#    <div style= "font-size: 28px;font-weight:bold;margin-top:20px;margin-bottom:20px;margin-left:360px;margin-right:140px; line-height: 1.1;color:#6f800f;"><center>ML Project | To Grant or Not to Grant</center></div>
#    <div style= "font-size: 17px;font-weight:bold;"><center>Fall Semester | 2024 - 2025</center></div>
#    <div><center><b>Master in Data Science and Advanced Analytics</b> </center></div>
#  <br>
#     <div><center>André Silvestre, 20240502 </center></div>
#     <div><center>João Henriques, 20240499 </center></div>
#     <div><center>Vinícius Pinto, 20211682 </center></div>
#     <div><center>Simone Genovese, 20241459 </center></div>
#     <div><center>Zofia Wojcik, 20240654 </center></div>
#     <br>
#     <div><center><b>TBL Group 33</b></center></div>
#  <br>

# %% [markdown]
# <div style="background: linear-gradient(to right,#6f800f, #6f800f);
#             padding: .7px; color: white; border-radius: 300px; text-align: center;">
# </div>

# %% [markdown]
# ## Business Understanding | Introduction
#
# The New York Workers’ Compensation Board (WCB) administers and regulates workers’ compensation, disability, volunteer firefighters, volunteer ambulance workers, and volunteer civil defence  workers’ benefits. As the regulating authority, the WCB is  responsible  for  **assembling and deciding on claims whenever it becomes aware of a workplace injury**. Since 2000, the WCB has assembled and reviewed more than 5 million claims.
#
# However, manually reviewing all claims is an arduous and time-consuming process. For that reason, the WCB has reached out to Nova IMS to assist them in the creation of a model that can automate the decision-making whenever a new claim is received.
#
#
# ### Project Goals <br>
#
# 1.	**Multiclass Classification Benchmarking:** Create a classification model that can accurately predict the WCB’s final decision on what type of injury (Claim Injury Type) should be given to a claim. To do that, the WCB has provided labelled data with all claims  assembled  between  2020 and 2022. You will need to develop  a  consistent  model assessment strategy that will allow you to create  and  compare different candidate models to find the most generalizable one.
#
# 2.	**Model Optimization:** After selecting your best (or set of best) models, you are encouraged to explore ways to improve their performance (e.g. hyper-parameter tuning or pre-processing/feature selection adjustments).
#
# 3.	**Additional Insights:** This project segment is open-ended, meaning you can explore as many ideas as you desire (as long as you make them explicit and understandable). Here are some possible suggestions:
#
# <br>
#
# ### Dataset Attributes
#
# |         |            **ATTRIBUTE**            | **DESCRIPTION**                                                                                                                                                                                                                                           |
# |:-------:|:-----------------------------------:|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  **1**  |            Accident Date            | Injury date of the claim.                                                                                                                                                                                                                                 |
# |  **2**  |            Age at Injury            | Age of injured worker when the injury occurred.                                                                                                                                                                                                           |
# |  **3**  |   Alternative Dispute Resolution    | Adjudication processes external to the Board.                                                                                                                                                                                                             |
# |  **4**  |            Assembly Date            | The date the claim was first assembled.                                                                                                                                                                                                                   |
# |  **5**  |       Attorney/Representative       | Is the claim being represented by an Attorney?                                                                                                                                                                                                            |
# |  **6**  |         Average Weekly Wage         | The wage used to calculate workers' compensation, disability, or Paid Leave wage replacement benefits.                                                                                                                                                    |
# |  **7**  |             Birth Year              | The reported year of birth of the injured worker.                                                                                                                                                                                                         |
# |  **8**  |              C-2 Date               | Date of receipt of the Employer's Report of Work-Related Injury/Illness or equivalent (formerly Form C-2).                                                                                                                                                |
# |  **9**  |              C-3 Date               | Date From C-3 (Employee Claim Form) was received.                                                                                                                                                                                                         |
# | **10**  |            Carrier Name             | Name of primary insurance provider responsible for providing workers' compensation coverage to the injured worker's employer.                                                                                                                             |
# | **11**  |            Carrier Type             | Type of primary insurance provider responsible for providing workers' compensation coverage.                                                                                                                                                              |
# | **12**  |          Claim Identifier           | Unique identifier for each claim, assigned by WCB.                                                                                                                                                                                                        |
# | **13**  |          County of Injury           | Name of the New York County where the injury occurred.                                                                                                                                                                                                    |
# | **14**  |         COVID-19 Indicator          | Indication that the claim may be associated with COVID-19.                                                                                                                                                                                                |
# | **15**  |            District Name            | Name of the WCB district office that oversees claims for that region or area of the state.                                                                                                                                                                |
# | **16**  |         First Hearing Date          | Date the first hearing was held on a claim at a WCB hearing location. A blank date means the claim has not yet had a hearing held.                                                                                                                        |
# | **17**  |               Gender                | The reported gender of the injured worker.                                                                                                                                                                                                                |
# | **18**  |             IME-4 Count             | Number of IME-4 forms received per claim. The IME-4 form is the "Independent Examiner's Report of Independent Medical Examination" form.                                                                                                                  |
# | **19**  |            Industry Code            | [NAICS code and descriptions](https://www.naics.com/search-naics-codes-by-industry/).                                                                                                                                                                     |
# | **20**  |      Industry Code Description      | 2-digit NAICS industry code description used to classify businesses according to their economic activity.                                                                                                                                                 |
# | **21**  |         Medical Fee Region          | Approximate region where the injured worker would receive medical service.                                                                                                                                                                                |
# | **22**  | OIICS Nature of Injury Description  | [The OIICS nature of injury codes & descriptions](https://www.bls.gov/iif/oiics_manual_2007.pdf).                                                                                                                                                         |
# | **23**  |      WCIO Cause of Injury Code      | [The WCIO cause of injury codes & descriptions](https://www.wcio.org/Active%20PNC/WCIO_Cause_Table.pdf).                                                                                                                                                  |
# | **24**  |  WCIO Cause of Injury Description   | See description of field above.                                                                                                                                                                                                                           |
# | **25**  |     WCIO Nature of Injury Code      | [The WCIO nature of injury](https://www.wcio.org/Active%20PNC/WCIO_Nature_Table.pdf).                                                                                                                                                                     |
# | **26**  |  WCIO Nature of Injury Description  | See description of field above.                                                                                                                                                                                                                           |
# | **27**  |       WCIO Part Of Body Code        | [The WCIO part of body codes & descriptions](https://www.wcio.org/Active%20PNC/WCIO_Part_Table.pdf).                                                                                                                                                      |
# | **28**  |    WCIO Part Of Body Description    | See description of field above.                                                                                                                                                                                                                           |
# | **29**  |              Zip Code               | The reported ZIP code of the injured worker's home address.                                                                                                                                                                                               |
# | **30**  |          Agreement Reached          | Binary variable: Yes if there is an agreement without the involvement of the WCB -> unknown at the start of a claim.                                                                                                                                      |
# | **31**  |            WCB Decision             | Multiclass variable: Decision of the WCB relative to the claim: `Accident` means that claim refers to workplace accident, <br/> `Occupational Disease` means illness from the workplace. -> requires WCB deliberation so it is unknown at start of claim. |
# | **32**  |          Claim Injury Type          | **Main target variable:** Deliberation of the WCB relative to benefits awarded to the claim. Numbering indicates severity.                                                                                                                                |

# %% [markdown]
# <div style="background: linear-gradient(to right,#6f800f, #6f800f);
#             padding: .7px; color: white; border-radius: 300px; text-align: center;">
# </div>

# %% [markdown]
# ## 📚 Libraries Import

# %%
# For data
import pandas as pd
import numpy as np
import os

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import matplotlib.lines as mlines
import missingno as msno

# For data preprocessing
from sklearn.model_selection import train_test_split

# For modeling

# For model evaluation



# Set the style of the visualization
pd.set_option('display.max_columns', None) # display all columns

# for better resolution plots
# %config InlineBackend.figure_format = 'retina' # optionally, you can change 'svg' to 'retina'

# Setting seaborn style
sns.set_theme(style="white")

# %% [markdown]
# ## 🧮 Import Databases

# %%
# Importing the dataset
train_data = pd.read_csv('data/train_data.csv', low_memory=False)   # low_memory=False to avoid warning message about mixed types
test_data = pd.read_csv('data/test_data.csv')

# %%
# Display the first 2 rows of each dataset
train_data.head(2)
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2019-12-30           31.0                              N    2020-01-01
# 1    2019-08-30           46.0                              N    2020-01-01
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                 0.00      1988.0  2019-12-31
# 1                       Y              1745.93      1973.0  2020-01-01
#
#      C-3 Date                  Carrier Name Carrier Type  Claim Identifier  \
# 0         NaN    NEW HAMPSHIRE INSURANCE CO  1A. PRIVATE           5393875
# 1  2020-01-14  ZURICH AMERICAN INSURANCE CO  1A. PRIVATE           5393091
#
#   Claim Injury Type County of Injury COVID-19 Indicator District Name  \
# 0       2. NON-COMP     ST. LAWRENCE                  N      SYRACUSE
# 1      4. TEMPORARY          WYOMING                  N     ROCHESTER
#
#   First Hearing Date Gender  IME-4 Count  Industry Code  \
# 0                NaN      M          NaN           44.0
# 1         2020-02-21      F          4.0           23.0
#
#   Industry Code Description Medical Fee Region  \
# 0              RETAIL TRADE                  I
# 1              CONSTRUCTION                  I
#
#    OIICS Nature of Injury Description  WCIO Cause of Injury Code  \
# 0                                 NaN                       27.0
# 1                                 NaN                       97.0
#
#   WCIO Cause of Injury Description  WCIO Nature of Injury Code  \
# 0     FROM LIQUID OR GREASE SPILLS                        10.0
# 1                REPETITIVE MOTION                        49.0
#
#   WCIO Nature of Injury Description  WCIO Part Of Body Code  \
# 0                         CONTUSION                    62.0
# 1                    SPRAIN OR TEAR                    38.0
#
#   WCIO Part Of Body Description Zip Code  Agreement Reached      WCB Decision  \
# 0                      BUTTOCKS    13662                0.0  Not Work Related
# 1                   SHOULDER(S)    14569                1.0  Not Work Related
#
#    Number of Dependents
# 0                   1.0
# 1                   4.0

# %%
test_data.head(2)
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2022-12-24             19                              N    2023-01-02
# 1    2022-11-20             19                              N    2023-01-02
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                  NaN      2003.0  2023-01-02
# 1                       N                  NaN      2003.0  2023-01-02
#
#   C-3 Date               Carrier Name Carrier Type  Claim Identifier  \
# 0      NaN  INDEMNITY INSURANCE CO OF  1A. PRIVATE           6165911
# 1      NaN    A I U INSURANCE COMPANY  1A. PRIVATE           6166141
#
#   County of Injury COVID-19 Indicator District Name First Hearing Date Gender  \
# 0            BRONX                  N           NYC                NaN      M
# 1           QUEENS                  N           NYC                NaN      F
#
#    IME-4 Count  Industry Code       Industry Code Description  \
# 0          NaN           48.0  TRANSPORTATION AND WAREHOUSING
# 1          NaN           45.0                    RETAIL TRADE
#
#   Medical Fee Region  OIICS Nature of Injury Description  \
# 0                 IV                                 NaN
# 1                 IV                                 NaN
#
#    WCIO Cause of Injury Code WCIO Cause of Injury Description  \
# 0                       31.0          FALL, SLIP OR TRIP, NOC
# 1                       75.0         FALLING OR FLYING OBJECT
#
#    WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 0                        10.0                         CONTUSION
# 1                        10.0                         CONTUSION
#
#    WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 0                    54.0                     LOWER LEG    10466
# 1                    10.0          MULTIPLE HEAD INJURY    11691
#
#    Number of Dependents
# 0                     1
# 1                     1

# %%
# Number of rows and columns
print('\033[1mTrain Dataset \033[0m')
print('  Number of rows:', train_data.shape[0])
print('  Number of columns:', train_data.shape[1])

print('\n\033[1mTest Dataset \033[0m')
print('  Number of rows:', test_data.shape[0])
print('  Number of columns:', test_data.shape[1])
# Out:
# Train Dataset
#   Number of rows: 593471
#   Number of columns: 33
#
# Test Dataset
#   Number of rows: 387975
#   Number of columns: 30

# %%
# Columns that train_data have more than test_data
train_data.columns.difference(test_data.columns)
# Out:
# Index(['Agreement Reached', 'Claim Injury Type', 'WCB Decision'], dtype='object')

# %% [markdown]
# #### Notes
# - `Claim Injury Type` is the target variable
# - `WCB Decision` and `Agreement Reached` are not present in the test dataset so they will be dropped from the train dataset because they are not useful for the model.

# %%
# Drop columns that are not present in the test dataset
train_data.drop(columns=['WCB Decision', 'Agreement Reached'], inplace=True)

# %%
# Check for missing values (n = number of missing values & % = percentage of missing values)
pd.DataFrame({'n NAs | Train': train_data.isnull().sum(), 
              '% NAs | Train': round(train_data.isnull().mean() * 100,2),
              'n NAs | Test': test_data.isnull().sum(),
              '% NAs | Test': round(test_data.isnull().mean() * 100,2)})
# Out:
#                                     n NAs | Train  % NAs | Train  \
# Accident Date                               23134           3.90
# Age at Injury                               19445           3.28
# Alternative Dispute Resolution              19445           3.28
# Assembly Date                                   0           0.00
# Attorney/Representative                     19445           3.28
# Average Weekly Wage                         48096           8.10
# Birth Year                                  48523           8.18
# C-2 Date                                    34005           5.73
# C-3 Date                                   406226          68.45
# COVID-19 Indicator                          19445           3.28
# Carrier Name                                19445           3.28
# Carrier Type                                19445           3.28
# Claim Identifier                                0           0.00
# Claim Injury Type                           19445           3.28
# County of Injury                            19445           3.28
# District Name                               19445           3.28
# First Hearing Date                         442673          74.59
# Gender                                      19445           3.28
# IME-4 Count                                460668          77.62
# Industry Code                               29403           4.95
# Industry Code Description                   29403           4.95
# Medical Fee Region                          19445           3.28
# Number of Dependents                        19445           3.28
# OIICS Nature of Injury Description         593471         100.00
# WCIO Cause of Injury Code                   35085           5.91
# WCIO Cause of Injury Description            35085           5.91
# WCIO Nature of Injury Code                  35102           5.91
# WCIO Nature of Injury Description           35102           5.91
# WCIO Part Of Body Code                      36527           6.15
# WCIO Part Of Body Description               36527           6.15
# Zip Code                                    48082           8.10
#
#                                     n NAs | Test  % NAs | Test
# Accident Date                             2444.0          0.63
# Age at Injury                                0.0          0.00
# Alternative Dispute Resolution               0.0          0.00
# Assembly Date                                0.0          0.00
# Attorney/Representative                      0.0          0.00
# Average Weekly Wage                      19204.0          4.95
# Birth Year                               19470.0          5.02
# C-2 Date                                  9134.0          2.35
# C-3 Date                                302759.0         78.04
# COVID-19 Indicator                           0.0          0.00
# Carrier Name                                 0.0          0.00
# Carrier Type                                 0.0          0.00
# Claim Identifier                             0.0          0.00
# Claim Injury Type                            NaN           NaN
# County of Injury                             0.0          0.00
# District Name                                0.0          0.00
# First Hearing Date                      344947.0         88.91
# Gender                                       0.0          0.00
# IME-4 Count                             352726.0         90.91
# Industry Code                             7736.0          1.99
# Industry Code Description                 7736.0          1.99
# Medical Fee Region                           0.0          0.00
# Number of Dependents                         0.0          0.00
# OIICS Nature of Injury Description      387975.0        100.00
# WCIO Cause of Injury Code                10348.0          2.67
# WCIO Cause of Injury Description         10348.0          2.67
# WCIO Nature of Injury Code               10560.0          2.72
# WCIO Nature of Injury Description        10560.0          2.72
# WCIO Part Of Body Code                    9549.0          2.46
# WCIO Part Of Body Description             9549.0          2.46
# Zip Code                                 19342.0          4.99

# %%
# Visualize the missing values in the dataset
msno.matrix(train_data, labels=True, sort="descending");

# %% [markdown]
# ---
#
# ### Notes | Missing Values
#
# In a 1st analysis, we can see that there are some columns with a high percentage of missing values.
#
# - **`OIICS Nature of Injury Description`** ($100\%$) just has missing values in train dataset so it will be dropped.
# - **`C-3 Date`** ($68.45\%$), **`First Hearing Date`** ($74.59\%$), **`IME-4 Count`** ($77.62\%$) have a high percentage of missing values so they will be dropped because they are not useful for the model and it is not possible to impute them without biasing a lot the model.
#
#
#
# ---

# %%
# Drop columns with high percentage of missing values
train_data.drop(columns=['OIICS Nature of Injury Description', 'C-3 Date', 'First Hearing Date', 'IME-4 Count'], inplace=True)
test_data.drop(columns=['OIICS Nature of Injury Description', 'C-3 Date', 'First Hearing Date', 'IME-4 Count'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Drop columns with high percentage of missing values
# ----> 2 train_data.drop(columns=['OIICS Nature of Injury Description', 'C-3 Date', 'First Hearing Date', 'IME-4 Count'], inplace=True)
#       3 test_data.drop(columns=['OIICS Nature of Injury Description', 'C-3 Date', 'First Hearing Date', 'IME-4 Count'], inplace=True)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['OIICS Nature of Injury Description', 'C-3 Date', 'First Hearing Date', 'IME-4 Count'] not found in axis"

# %%
# Check for duplicates rows by costumer_id
train_data.duplicated().sum()
# Out:
# 0

# %%
test_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ---

# %%
# Check the data types
train_data.dtypes
# Out:
# Accident Date                         object
# Age at Injury                        float64
# Alternative Dispute Resolution        object
# Assembly Date                         object
# Attorney/Representative               object
# Average Weekly Wage                  float64
# Birth Year                           float64
# C-2 Date                              object
# Carrier Name                          object
# Carrier Type                          object
# Claim Identifier                       int64
# Claim Injury Type                     object
# County of Injury                      object
# COVID-19 Indicator                    object
# District Name                         object
# Gender                                object
# Industry Code                        float64
# Industry Code Description             object
# Medical Fee Region                    object
# WCIO Cause of Injury Code            float64
# WCIO Cause of Injury Description      object
# WCIO Nature of Injury Code           float64
# WCIO Nature of Injury Description     object
# WCIO Part Of Body Code               float64
# WCIO Part Of Body Description         object
# Zip Code                              object
# Number of Dependents                 float64
# dtype: object

# %% [markdown]
# ### Notes | Data Types
#
# - **`Accident Date`**, **`Assembly Date`** and **`C-2 Date`** are in `object` format so they will be converted to `datetime` format.
# - **`Age at Injury`** and **`Birth Year`** is in `float64` format so it will be converted to `Int64` format.
# - **`Attorney/Representative`** will be converted to `bool` format $\rightarrow$ `True` if the claim is being represented by an Attorney/Representative and `False` otherwise.
# - **`Carrier Type`** will be converted to `category` format $\rightarrow$ Type of primary insurance provider whose coverage pertains to the injured
# worker (Private Carrier, State Insurance Fund, Selfinsured, or Special Fund).
# - **`Claim Identifier`** is the unique identifier for each claim
# - **`Claim Injury Type`** is the target variable that will be converted to `category` format:
#     - **1. NON-COMP –** No compensation for the claim,
#     - **2. MED ONLY –** The claims will pay out Medicals only,
#     - **3. TEMP TOTAL –** Claim type involving loss of time,
#     - **4. PPD SCH LOSS –** Scheduled Loss payment involving a part of body,
#     - **5. PPD NSL –** Permanent Partial Non Scheduled Loss,
#     - **6. PTD –** Permanent Total Disability
#     - **7. DEATH –** A claim involving a deceased claimant.
#     - **8. UNKNOWN –** information is not available or does not apply
#     <br>
# - **`COVID-19 Indicator`** will be converted to `bool` format $\rightarrow$ `True` if the claim may be associated with COVID-19 and `False` otherwise.
# - **`Gender`** will be converted to `category` format $\rightarrow$ `F` - Female, `M` -Male and `U` – Unknown (gender was not specified)
# - **`Industry Code`** will be converted to `category` format $\rightarrow$ NAICS code and descriptions
# - **`WCIO Cause of Injury Code`** will be converted to `category` format $\rightarrow$ The WCIO cause of injury codes & descriptions
# - **`WCIO Nature of Injury Code`** will be converted to `category` format $\rightarrow$ The WCIO nature of injury codes & descriptions
# - **`WCIO Part Of Body Code`** will be converted to `category` format $\rightarrow$ The WCIO part of body codes & descriptions

# %% [markdown]
# ---

# %%
# Convert columns to datetime format
train_data['Accident Date'] = pd.to_datetime(train_data['Accident Date'])
train_data['Assembly Date'] = pd.to_datetime(train_data['Assembly Date'])
train_data['C-2 Date'] = pd.to_datetime(train_data['C-2 Date'])

test_data['Accident Date'] = pd.to_datetime(test_data['Accident Date'])
test_data['Assembly Date'] = pd.to_datetime(test_data['Assembly Date'])
test_data['C-2 Date'] = pd.to_datetime(test_data['C-2 Date'])

# %%
# Convert columns to Int64 format
train_data['Age at Injury'] = train_data['Age at Injury'].astype('Int64')
train_data['Birth Year'] = train_data['Birth Year'].astype('Int64')

test_data['Age at Injury'] = test_data['Age at Injury'].astype('Int64')
test_data['Birth Year'] = test_data['Birth Year'].astype('Int64')

# %%
# Discritive statistics
round(train_data.describe(include="all").T, 2)
# Out:
#                                       count unique  \
# Accident Date                        570337    NaN
# Age at Injury                      574026.0   <NA>
# Alternative Dispute Resolution       574026      3
# Assembly Date                        593471    NaN
# Attorney/Representative              574026      2
# Average Weekly Wage                545375.0    NaN
# Birth Year                         544948.0   <NA>
# C-2 Date                             559466    NaN
# Carrier Name                         574026   2046
# Carrier Type                         574026      8
# Claim Identifier                   593471.0    NaN
# Claim Injury Type                    574026      8
# County of Injury                     574026     63
# COVID-19 Indicator                   574026      2
# District Name                        574026      8
# Gender                               574026      4
# Industry Code                      564068.0    NaN
# Industry Code Description            564068     20
# Medical Fee Region                   574026      5
# WCIO Cause of Injury Code          558386.0    NaN
# WCIO Cause of Injury Description     558386     74
# WCIO Nature of Injury Code         558369.0    NaN
# WCIO Nature of Injury Description    558369     56
# WCIO Part Of Body Code             556944.0    NaN
# WCIO Part Of Body Description        556944     54
# Zip Code                             545389   8286
# Number of Dependents               574026.0    NaN
#
#                                                                  top    freq  \
# Accident Date                                                    NaN     NaN
# Age at Injury                                                   <NA>    <NA>
# Alternative Dispute Resolution                                     N  571412
# Assembly Date                                                    NaN     NaN
# Attorney/Representative                                            N  392291
# Average Weekly Wage                                              NaN     NaN
# Birth Year                                                      <NA>    <NA>
# C-2 Date                                                         NaN     NaN
# Carrier Name                                    STATE INSURANCE FUND  111144
# Carrier Type                                             1A. PRIVATE  285368
# Claim Identifier                                                 NaN     NaN
# Claim Injury Type                                        2. NON-COMP  291078
# County of Injury                                             SUFFOLK   60430
# COVID-19 Indicator                                                 N  546505
# District Name                                                    NYC  270779
# Gender                                                             M  335218
# Industry Code                                                    NaN     NaN
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                IV  265981
# WCIO Cause of Injury Code                                        NaN     NaN
# WCIO Cause of Injury Description                             LIFTING   46610
# WCIO Nature of Injury Code                                       NaN     NaN
# WCIO Nature of Injury Description                     STRAIN OR TEAR  153373
# WCIO Part Of Body Code                                           NaN     NaN
# WCIO Part Of Body Description                        LOWER BACK AREA   51862
# Zip Code                                                       11236    3398
# Number of Dependents                                             NaN     NaN
#
#                                                             mean  \
# Accident Date                      2021-04-28 21:00:27.892982784
# Age at Injury                                           42.11427
# Alternative Dispute Resolution                               NaN
# Assembly Date                      2021-07-19 03:25:38.260841728
# Attorney/Representative                                      NaN
# Average Weekly Wage                                   491.088321
# Birth Year                                           1886.767604
# C-2 Date                           2021-07-16 20:11:19.865443328
# Carrier Name                                                 NaN
# Carrier Type                                                 NaN
# Claim Identifier                                 23667598.792812
# Claim Injury Type                                            NaN
# County of Injury                                             NaN
# COVID-19 Indicator                                           NaN
# District Name                                                NaN
# Gender                                                       NaN
# Industry Code                                          58.645305
# Industry Code Description                                    NaN
# Medical Fee Region                                           NaN
# WCIO Cause of Injury Code                              54.381143
# WCIO Cause of Injury Description                             NaN
# WCIO Nature of Injury Code                             41.013839
# WCIO Nature of Injury Description                            NaN
# WCIO Part Of Body Code                                 39.738146
# WCIO Part Of Body Description                                NaN
# Zip Code                                                     NaN
# Number of Dependents                                    3.006559
#
#                                                    min                  25%  \
# Accident Date                      1961-09-06 00:00:00  2020-09-14 00:00:00
# Age at Injury                                      0.0                 31.0
# Alternative Dispute Resolution                     NaN                  NaN
# Assembly Date                      2020-01-01 00:00:00  2020-10-26 00:00:00
# Attorney/Representative                            NaN                  NaN
# Average Weekly Wage                                0.0                  0.0
# Birth Year                                         0.0               1965.0
# C-2 Date                           1996-01-12 00:00:00  2020-11-06 00:00:00
# Carrier Name                                       NaN                  NaN
# Carrier Type                                       NaN                  NaN
# Claim Identifier                             5393066.0            5593414.5
# Claim Injury Type                                  NaN                  NaN
# County of Injury                                   NaN                  NaN
# COVID-19 Indicator                                 NaN                  NaN
# District Name                                      NaN                  NaN
# Gender                                             NaN                  NaN
# Industry Code                                     11.0                 45.0
# Industry Code Description                          NaN                  NaN
# Medical Fee Region                                 NaN                  NaN
# WCIO Cause of Injury Code                          1.0                 31.0
# WCIO Cause of Injury Description                   NaN                  NaN
# WCIO Nature of Injury Code                         1.0                 16.0
# WCIO Nature of Injury Description                  NaN                  NaN
# WCIO Part Of Body Code                            -9.0                 33.0
# WCIO Part Of Body Description                      NaN                  NaN
# Zip Code                                           NaN                  NaN
# Number of Dependents                               0.0                  1.0
#
#                                                    50%                  75%  \
# Accident Date                      2021-06-27 00:00:00  2022-03-21 00:00:00
# Age at Injury                                     42.0                 54.0
# Alternative Dispute Resolution                     NaN                  NaN
# Assembly Date                      2021-07-29 00:00:00  2022-04-19 00:00:00
# Attorney/Representative                            NaN                  NaN
# Average Weekly Wage                                0.0                841.0
# Birth Year                                      1977.0               1989.0
# C-2 Date                           2021-08-09 00:00:00  2022-04-26 00:00:00
# Carrier Name                                       NaN                  NaN
# Carrier Type                                       NaN                  NaN
# Claim Identifier                             5791212.0            5991000.5
# Claim Injury Type                                  NaN                  NaN
# County of Injury                                   NaN                  NaN
# COVID-19 Indicator                                 NaN                  NaN
# District Name                                      NaN                  NaN
# Gender                                             NaN                  NaN
# Industry Code                                     61.0                 71.0
# Industry Code Description                          NaN                  NaN
# Medical Fee Region                                 NaN                  NaN
# WCIO Cause of Injury Code                         56.0                 75.0
# WCIO Cause of Injury Description                   NaN                  NaN
# WCIO Nature of Injury Code                        49.0                 52.0
# WCIO Nature of Injury Description                  NaN                  NaN
# WCIO Part Of Body Code                            38.0                 53.0
# WCIO Part Of Body Description                      NaN                  NaN
# Zip Code                                           NaN                  NaN
# Number of Dependents                               3.0                  5.0
#
#                                                    max               std
# Accident Date                      2023-09-29 00:00:00               NaN
# Age at Injury                                    117.0         14.256432
# Alternative Dispute Resolution                     NaN               NaN
# Assembly Date                      2022-12-31 00:00:00               NaN
# Attorney/Representative                            NaN               NaN
# Average Weekly Wage                          2828079.0        6092.91812
# Birth Year                                      2018.0        414.644423
# C-2 Date                           2024-06-01 00:00:00               NaN
# Carrier Name                                       NaN               NaN
# Carrier Type                                       NaN               NaN
# Claim Identifier                           999891667.0  107927137.907028
# Claim Injury Type                                  NaN               NaN
# County of Injury                                   NaN               NaN
# COVID-19 Indicator                                 NaN               NaN
# District Name                                      NaN               NaN
# Gender                                             NaN               NaN
# Industry Code                                     92.0         19.644175
# Industry Code Description                          NaN               NaN
# Medical Fee Region                                 NaN               NaN
# WCIO Cause of Injury Code                         99.0         25.874281
# WCIO Cause of Injury Description                   NaN               NaN
# WCIO Nature of Injury Code                        91.0         22.207521
# WCIO Nature of Injury Description                  NaN               NaN
# WCIO Part Of Body Code                            99.0          22.36594
# WCIO Part Of Body Description                      NaN               NaN
# Zip Code                                           NaN               NaN
# Number of Dependents                               6.0          2.000801

# %% [markdown]
# ### Notes | Descriptive Statistics
#
# - **`Age at Injury`**: Average age (42.1 years) seems normal, but there is a potential anomaly with an age as high as 117 years. Also, there are ages with 0 years old that need to be checked because it can be a NaN value.
# - **`Accident Date`**: The dataset contains claims from 1961 to 2023, which seems reasonable.
# - **`Alternative Dispute Resolution`**: Values are consistent, with "N" being the dominant category.
# - **`Assembly Date`**: Date range from 2020 to 2022 is expected and seems fine.
# - **`Attorney/Representative`**: Most claims are not represented by attorneys, which seems typical.
# - **`Average Weekly Wage`**: The average wage is reasonable, but there is at least one outlier with a salary as high as $\$2,828,079$, compared to the average of $\$491$.
# - **`Birth Year`**: Some inconsistent values, especially with 0 as a birth year, indicating potential data errors.
# - **`C-2 Date`**: Date values range from 1996 to 2024, which is within the expected range.
# - **`Carrier Name`**: "STATE INSURANCE FUND" is the most frequent -> Need a EDA to check other classes.
# - **`Carrier Type`**: "1A. PRIVATE" being the most frequent -> Need a EDA to check other classes.
# - **`Claim Identifier`**: Unique identifiers for each claim -> Already checked for duplicates.
# - **`Claim Injury Type`**: "2. NON-COMP" is the most frequent -> Need a EDA to check other classes.
# - **`County of Injury`**: "SUFFOLK" is the most common -> Need a EDA to check other classes.
# - **`COVID-19 Indicator`**: Most claims are not related to COVID-19.
# - **`District Name`**: "NYC" being the most frequent district -> Need a EDA to check other classes.
# - **`Gender`**: "M" being the most frequent -> Need a EDA to check other classes.
# - **`Industry Code`**: Codes that need to be categorical [descriptions](https://www.naics.com/search-naics-codes-by-industry/).
# - **`Industry Code Description`**: "HEALTH CARE AND SOCIAL ASSISTANCE" is the most common -> Need a EDA to check other classes.
# - **`Medical Fee Region`**: Region "IV" is most frequent -> Need a EDA to check other classes.
# - **`WCIO Cause of Injury Code`**: Codes that need to be categorical [descriptions](https://www.dir.ca.gov/dwc/WCIS/Cause_Of_Injury.pdf).
# - **`WCIO Cause of Injury Description`**: Descriptions in text format that have the same information as the codes in text format.
# - **`WCIO Nature of Injury Code`**: Codes that need to categorical [descriptions](https://www.dir.ca.gov/dwc/WCIS/Nature_Of_Injury.pdf).
# - **`WCIO Nature of Injury Description`**: Descriptions in text format that have the same information as the codes in text format.
# - **`WCIO Part Of Body Code`**: Codes that need to be categorical [descriptions](https://www.guarantysupport.com/wp-content/uploads/2024/02/WCIO-Legacy.pdf).
# - **`Zip Code`**: Neet to be converted to `int64` format.

# %% [markdown]
# ---

# %%
# Check the cases where the age is 0
print('The number of cases where the age is 0:', train_data[train_data['Age at Injury'] == 0].shape[0], '(', round(train_data[train_data['Age at Injury'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')
train_data[train_data['Age at Injury'] == 0]
# Out:
# The number of cases where the age is 0: 5464 ( 0.92 %)
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 262       2019-06-26              0                              N
# 358       2019-12-28              0                              N
# 370              NaT              0                              N
# 396              NaT              0                              N
# 433       2019-12-20              0                              N
# ...              ...            ...                            ...
# 592964           NaT              0                              N
# 592978           NaT              0                              N
# 593063           NaT              0                              N
# 593087    2022-12-13              0                              N
# 593265    2022-11-19              0                              N
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 262       2020-01-02                       N                  0.0           0
# 358       2020-01-02                       N                  0.0           0
# 370       2020-01-02                       Y                  0.0        1959
# 396       2020-01-02                       Y                  0.0        1984
# 433       2020-01-02                       N                  0.0           0
# ...              ...                     ...                  ...         ...
# 592964    2022-12-30                       Y                  0.0           0
# 592978    2022-12-30                       Y                  0.0        1972
# 593063    2022-12-30                       Y                  0.0        1957
# 593087    2022-12-30                       N                  0.0        1903
# 593265    2022-12-30                       N                  0.0           0
#
#          C-2 Date                    Carrier Name      Carrier Type  \
# 262           NaT    AMERICAN ZURICH INSURANCE CO       1A. PRIVATE
# 358    2019-12-30          TWIN CITY FIRE INS CO.       1A. PRIVATE
# 370           NaT  STARR INDEMNITY & LIABILITY CO       1A. PRIVATE
# 396           NaT               LM INSURANCE CORP       1A. PRIVATE
# 433    2019-12-30  CARMEL CENTRAL SCHOOL DISTRICT   3A. SELF PUBLIC
# ...           ...                             ...               ...
# 592964 2023-01-10           NYC TRANSIT AUTHORITY   3A. SELF PUBLIC
# 592978 2023-01-20               LM INSURANCE CORP       1A. PRIVATE
# 593063        NaT    CNY OTHER THAN ED, HED WATER   3A. SELF PUBLIC
# 593087 2022-12-30  SECURITY NATIONAL INSURANCE CO       1A. PRIVATE
# 593265 2022-12-30   NEW YORK BLACK CAR OPERATORS'  4A. SELF PRIVATE
#
#         Claim Identifier Claim Injury Type County of Injury  \
# 262              5393971       2. NON-COMP           NASSAU
# 358              5394093       2. NON-COMP         NEW YORK
# 370              5394068       2. NON-COMP            BRONX
# 396              5393794       2. NON-COMP         ONONDAGA
# 433              5393876       2. NON-COMP           PUTNAM
# ...                  ...               ...              ...
# 592964           6164179       2. NON-COMP          SUFFOLK
# 592978           6164933       2. NON-COMP            KINGS
# 593063           6164931      1. CANCELLED            KINGS
# 593087           6164433       2. NON-COMP           ALBANY
# 593265           6165637       2. NON-COMP           QUEENS
#
#        COVID-19 Indicator District Name Gender  Industry Code  \
# 262                     N           NYC      M           62.0
# 358                     N           NYC      M           71.0
# 370                     N           NYC      M           23.0
# 396                     N      SYRACUSE      F            NaN
# 433                     N        ALBANY      F            NaN
# ...                   ...           ...    ...            ...
# 592964                  N     HAUPPAUGE      M           48.0
# 592978                  N           NYC      M           23.0
# 593063                  N           NYC      M            NaN
# 593087                  N        ALBANY      F           62.0
# 593265                  N           NYC      M           48.0
#
#                   Industry Code Description Medical Fee Region  \
# 262       HEALTH CARE AND SOCIAL ASSISTANCE                 IV
# 358     ARTS, ENTERTAINMENT, AND RECREATION                 IV
# 370                            CONSTRUCTION                 IV
# 396                                     NaN                 II
# 433                                     NaN                III
# ...                                     ...                ...
# 592964       TRANSPORTATION AND WAREHOUSING                 UK
# 592978                         CONSTRUCTION                 IV
# 593063                                  NaN                 IV
# 593087    HEALTH CARE AND SOCIAL ASSISTANCE                 II
# 593265       TRANSPORTATION AND WAREHOUSING                 UK
#
#         WCIO Cause of Injury Code  \
# 262                           NaN
# 358                          55.0
# 370                           NaN
# 396                           NaN
# 433                          74.0
# ...                           ...
# 592964                       99.0
# 592978                       60.0
# 593063                        NaN
# 593087                       17.0
# 593265                       45.0
#
#                    WCIO Cause of Injury Description  \
# 262                                             NaN
# 358                             HOLDING OR CARRYING
# 370                                             NaN
# 396                                             NaN
# 433          FELLOW WORKER, PATIENT OR OTHER PERSON
# ...                                             ...
# 592964                   OTHER - MISCELLANEOUS, NOC
# 592978                     STRAIN OR INJURY BY, NOC
# 593063                                          NaN
# 593087               OBJECT BEING LIFTED OR HANDLED
# 593265  COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
#
#         WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 262                            NaN                               NaN
# 358                           52.0                    STRAIN OR TEAR
# 370                            NaN                               NaN
# 396                            NaN                               NaN
# 433                           40.0                        LACERATION
# ...                            ...                               ...
# 592964                        78.0            CARPAL TUNNEL SYNDROME
# 592978                        78.0            CARPAL TUNNEL SYNDROME
# 593063                         NaN                               NaN
# 593087                        43.0                          PUNCTURE
# 593265                         1.0                NO PHYSICAL INJURY
#
#         WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 262                        NaN                           NaN    11801
# 358                       61.0       ABDOMEN INCLUDING GROIN      NaN
# 370                        NaN                           NaN      NaN
# 396                        NaN                           NaN    13212
# 433                       35.0                          HAND    10512
# ...                        ...                           ...      ...
# 592964                    -9.0                      MULTIPLE    22473
# 592978                    39.0           WRIST (S) & HAND(S)    11221
# 593063                     NaN                           NaN    11221
# 593087                    36.0                     FINGER(S)    12309
# 593265                    66.0            NO PHYSICAL INJURY    07666
#
#         Number of Dependents
# 262                      1.0
# 358                      5.0
# 370                      6.0
# 396                      4.0
# 433                      0.0
# ...                      ...
# 592964                   3.0
# 592978                   6.0
# 593063                   0.0
# 593087                   1.0
# 593265                   6.0
#
# [5464 rows x 27 columns]

# %%
# Check the cases where the birth year is 0
print('The number of cases where the birth year is 0:', train_data[train_data['Birth Year'] == 0].shape[0], '(', round(train_data[train_data['Birth Year'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')
train_data[train_data['Birth Year'] == 0]
# Out:
# The number of cases where the birth year is 0: 25081 ( 4.23 %)
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 11        2019-12-14             21                              N
# 47        2019-12-18             53                              N
# 56        2019-12-26             21                              N
# 77        2019-12-12             57                              N
# 83        2019-12-17             42                              N
# ...              ...            ...                            ...
# 593291    2022-11-30             44                              N
# 593361    2022-12-26             22                              N
# 593394    2022-12-28             31                              N
# 593427    2022-12-28             70                              N
# 593441    2022-11-27             19                              N
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 11        2020-01-01                       N                  0.0           0
# 47        2020-01-01                       N                  0.0           0
# 56        2020-01-01                       N                  0.0           0
# 77        2020-01-01                       N                  0.0           0
# 83        2020-01-01                       N                  0.0           0
# ...              ...                     ...                  ...         ...
# 593291    2022-12-30                       Y                  0.0           0
# 593361    2022-12-30                       N                  0.0           0
# 593394    2022-12-30                       N                  0.0           0
# 593427    2022-12-30                       Y                  NaN           0
# 593441    2022-12-30                       N                  0.0           0
#
#          C-2 Date                   Carrier Name     Carrier Type  \
# 11     2019-12-31    INDEMNITY INS. OF N AMERICA      1A. PRIVATE
# 47     2020-01-01         TWIN CITY FIRE INS CO.      1A. PRIVATE
# 56     2020-01-01  HARTFORD ACCIDENT & INDEMNITY      1A. PRIVATE
# 77     2019-12-31           NATIONAL CASUALTY CO      1A. PRIVATE
# 83     2019-12-31    INDEMNITY INS. OF N AMERICA      1A. PRIVATE
# ...           ...                            ...              ...
# 593291 2023-01-30   *** CARRIER UNDETERMINED ***          UNKNOWN
# 593361 2022-12-30    INDEMNITY INS. OF N AMERICA      1A. PRIVATE
# 593394 2022-12-30   AMERICAN ZURICH INSURANCE CO      1A. PRIVATE
# 593427 2022-12-30          NYC HOUSING AUTHORITY  3A. SELF PUBLIC
# 593441 2022-12-30   ARCH INDEMNITY INSURANCE CO.      1A. PRIVATE
#
#         Claim Identifier Claim Injury Type County of Injury  \
# 11               5394187       2. NON-COMP         NEW YORK
# 47               5394053       2. NON-COMP           WARREN
# 56               5393827       2. NON-COMP          SUFFOLK
# 77               5393885       2. NON-COMP     ST. LAWRENCE
# 83               5394008       2. NON-COMP         NEW YORK
# ...                  ...               ...              ...
# 593291           6164729       2. NON-COMP            BRONX
# 593361           6165113       2. NON-COMP         NEW YORK
# 593394           6165672       2. NON-COMP          UNKNOWN
# 593427           6164286      4. TEMPORARY           ORANGE
# 593441           6165627       2. NON-COMP           ORANGE
#
#        COVID-19 Indicator District Name Gender  Industry Code  \
# 11                      N           NYC      M           51.0
# 47                      N        ALBANY      F           72.0
# 56                      N     HAUPPAUGE      M           72.0
# 77                      N      SYRACUSE      M           62.0
# 83                      N           NYC      F           51.0
# ...                   ...           ...    ...            ...
# 593291                  N     STATEWIDE      M            NaN
# 593361                  N           NYC      F           51.0
# 593394                  N           NYC      M           42.0
# 593427                  N        ALBANY      M           92.0
# 593441                  N        ALBANY      M           32.0
#
#                 Industry Code Description Medical Fee Region  \
# 11                            INFORMATION                 UK
# 47        ACCOMMODATION AND FOOD SERVICES                  I
# 56        ACCOMMODATION AND FOOD SERVICES                III
# 77      HEALTH CARE AND SOCIAL ASSISTANCE                  I
# 83                            INFORMATION                 UK
# ...                                   ...                ...
# 593291                                NaN                 UK
# 593361                        INFORMATION                 UK
# 593394                    WHOLESALE TRADE                 UK
# 593427              PUBLIC ADMINISTRATION                 UK
# 593441                      MANUFACTURING                 UK
#
#         WCIO Cause of Injury Code  WCIO Cause of Injury Description  \
# 11                           75.0          FALLING OR FLYING OBJECT
# 47                            5.0               STEAM OR HOT FLUIDS
# 56                           16.0   HAND TOOL, UTENSIL; NOT POWERED
# 77                           32.0                    ON ICE OR SNOW
# 83                           97.0                 REPETITIVE MOTION
# ...                           ...                               ...
# 593291                        NaN                               NaN
# 593361                       31.0           FALL, SLIP OR TRIP, NOC
# 593394                       25.0  FROM DIFFERENT LEVEL (ELEVATION)
# 593427                       66.0    OBJECT BEING LIFTED OR HANDLED
# 593441                       17.0    OBJECT BEING LIFTED OR HANDLED
#
#         WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 11                            37.0                      INFLAMMATION
# 47                             4.0                              BURN
# 56                            40.0                        LACERATION
# 77                            28.0                          FRACTURE
# 83                            52.0                    STRAIN OR TEAR
# ...                            ...                               ...
# 593291                         NaN                               NaN
# 593361                        10.0                         CONTUSION
# 593394                        10.0                         CONTUSION
# 593427                        10.0                         CONTUSION
# 593441                        10.0                         CONTUSION
#
#         WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 11                        53.0                          KNEE    07649
# 47                        56.0                          FOOT    12810
# 56                        36.0                     FINGER(S)    11941
# 77                        44.0                         CHEST    13646
# 83                        38.0                   SHOULDER(S)      NaN
# ...                        ...                           ...      ...
# 593291                    -9.0                      MULTIPLE    44405
# 593361                    53.0                          KNEE    94603
# 593394                    41.0               UPPER BACK AREA    05743
# 593427                    32.0                         ELBOW    32164
# 593441                    11.0                         SKULL    75034
#
#         Number of Dependents
# 11                       3.0
# 47                       4.0
# 56                       3.0
# 77                       2.0
# 83                       2.0
# ...                      ...
# 593291                   6.0
# 593361                   3.0
# 593394                   1.0
# 593427                   1.0
# 593441                   1.0
#
# [25081 rows x 27 columns]

# %% [markdown]
# > We can try to impute the missing values in the `Age at Injury` column using the `Birth Year` column when the `Age at Injury` is 0 and the `Birth Year` is complete.

# %% [markdown]
# ---

# %%
# Check the unique values of each column except date columns
id_column = ['Claim Identifier']
dates_columns = ['Accident Date', 'Assembly Date', 'C-2 Date', 'First Hearing Date']
numeric_columns = train_data.select_dtypes(include='number').columns.difference(dates_columns)
numeric_columns
# Out:
# Index(['Age at Injury', 'Average Weekly Wage', 'Birth Year',
#        'Claim Identifier', 'Industry Code', 'Number of Dependents',
#        'WCIO Cause of Injury Code', 'WCIO Nature of Injury Code',
#        'WCIO Part Of Body Code'],
#       dtype='object')

# %%
# Check the unique values of each column except date columns and numeric columns
for col in train_data.columns.difference(dates_columns): #.difference(numeric_columns):
    unique_values = sorted(train_data[col].unique(), key=lambda x: (str(type(x)), x))
    print(f'\033[1m{col}\033[0m [{train_data[col].nunique()}]')
    # print(f'\033[1m{col}\033[0m [{train_data[col].nunique()}]: {unique_values} \n')
# Out:
# Age at Injury [108]
# Alternative Dispute Resolution [3]
# Attorney/Representative [2]
# Average Weekly Wage [120024]
# Birth Year [107]
# COVID-19 Indicator [2]
# Carrier Name [2046]
# Carrier Type [8]
# Claim Identifier [593470]
# Claim Injury Type [8]
# County of Injury [63]
# District Name [8]
# Gender [4]
# Industry Code [24]
# Industry Code Description [20]
# Medical Fee Region [5]
# Number of Dependents [7]
# WCIO Cause of Injury Code [77]
# WCIO Cause of Injury Description [74]
# WCIO Nature of Injury Code [56]
# WCIO Nature of Injury Description [56]
# WCIO Part Of Body Code [57]
# WCIO Part Of Body Description [54]
# Zip Code [8286]

# %% [markdown]
# ### Some Notes/Anomalies
#
# - **`Carrier Name`** has a lot of unique values (2046) that just can be useful if we do some text mining to extract information from the name. So it will be dropped.
# - **`County of Injury`** has some of unique values (63) so it will be converted to `category` format.
# - **`District Name`** has a (8) unique values, so it will be converted to `category` format.
# - **`Industry Code Description`** has some of unique values (20) so it will be converted to `category` format.
# - **`Medical Fee Region`** has (5) unique values so it will be converted to `category` format.
# - **`WCIO Cause of Injury Description`**, **`WCIO Nature of Injury Description`** and **`WCIO Part Of Body Description`** have a lot of unique values (74, 56 and 54) and they will be dropped, because we already have the codes.
# - **`Zip Code`** is a numerical column so it will be converted to `int64` format.
#
# The categories mentioned in the data description are confirmed and thus:
# - **`Gender`** will be converted to `category` format [`F` - Female, `M` - Male, `U` - Unknown].
# - **`COVID-19 Indicator`** has `True` and `False` values so it will be converted to `bool` format.
# - **`Attorney/Representative`** has `True` and `False` values so it will be converted to `bool` format.
# - **`Carrier Type`** has 8 unique values so it will be converted to `category` format.
# - **`Claim Injury Type`** has 8 unique values so it will be converted to `category` format.

# %% [markdown]
# ---

# %% [markdown]
# # 🔧 Data Pre-Proccessing

# %%
# Drop columns that are not useful for the model
train_data.drop(columns=['Carrier Name', 'WCIO Cause of Injury Description', 'WCIO Nature of Injury Description', 'WCIO Part Of Body Description'], inplace=True)
test_data.drop(columns=['Carrier Name', 'WCIO Cause of Injury Description', 'WCIO Nature of Injury Description', 'WCIO Part Of Body Description'], inplace=True)

# %%
# Convert columns to category format
train_data['County of Injury'] = train_data['County of Injury'].astype('category')
train_data['District Name'] = train_data['District Name'].astype('category')
train_data['Industry Code Description'] = train_data['Industry Code Description'].astype('category')
train_data['Medical Fee Region'] = train_data['Medical Fee Region'].astype('category')

test_data['County of Injury'] = test_data['County of Injury'].astype('category')
test_data['District Name'] = test_data['District Name'].astype('category')
test_data['Industry Code Description'] = test_data['Industry Code Description'].astype('category')
test_data['Medical Fee Region'] = test_data['Medical Fee Region'].astype('category')

# %% [markdown]
# ## 📊 EDA - Exploratory Data Analysis

# %% [markdown]
# ### **`Accident Date`**, **`Assembly Date`** and **`C-2 Date`**

# %%
# Describe the date columns
train_data[['Accident Date', 'Assembly Date', 'C-2 Date']].describe()
# Out:
#                        Accident Date                  Assembly Date  \
# count                         570337                         593471
# mean   2021-04-28 21:00:27.892982784  2021-07-19 03:25:38.260841728
# min              1961-09-06 00:00:00            2020-01-01 00:00:00
# 25%              2020-09-14 00:00:00            2020-10-26 00:00:00
# 50%              2021-06-27 00:00:00            2021-07-29 00:00:00
# 75%              2022-03-21 00:00:00            2022-04-19 00:00:00
# max              2023-09-29 00:00:00            2022-12-31 00:00:00
#
#                             C-2 Date
# count                         559466
# mean   2021-07-16 20:11:19.865443328
# min              1996-01-12 00:00:00
# 25%              2020-11-06 00:00:00
# 50%              2021-08-09 00:00:00
# 75%              2022-04-26 00:00:00
# max              2024-06-01 00:00:00

# %%
# Count of unique occurrences for 'Accident Date', 'Assembly Date', and 'C-2 Date'
accident_date_counts = train_data.groupby('Accident Date')['Claim Identifier'].nunique().reset_index(name='Total Accident Dates')
assembly_date_counts = train_data.groupby('Assembly Date')['Claim Identifier'].nunique().reset_index(name='Total Assembly Dates')
c2_date_counts = train_data.groupby('C-2 Date')['Claim Identifier'].nunique().reset_index(name='Total C-2 Dates')

# %%
# ------------------ Time Series of 'Accident Date', 'Assembly Date' and 'C-2 Date' ------------------
# Set the color palette for the different time series
palette = ['#BED62F', '#4E5813', '#FFB800']

# Create the figure and dual-axis plots for 'Accident Date', 'Assembly Date', and 'C-2 Date'
fig, ax1 = plt.subplots(figsize=(17,6))
ax2 = ax1.twinx()

# Plotting 'Accident Date' on ax1
sns.lineplot(data=accident_date_counts, x='Accident Date', y='Total Accident Dates', color=palette[0], ax=ax1, 
             linestyle='-', alpha=0.7, linewidth=1, marker='s', markersize=3)

# Plotting 'Assembly Date' on ax1 (same axis as 'Accident Date')
sns.lineplot(data=assembly_date_counts, x='Assembly Date', y='Total Assembly Dates', color=palette[1], ax=ax1, 
             linestyle='-', alpha=0.7, linewidth=1, marker='o', markersize=3)

# Plotting 'C-2 Date' on ax2
sns.lineplot(data=c2_date_counts, x='C-2 Date', y='Total C-2 Dates', color=palette[2], ax=ax2, 
             linestyle='-', alpha=0.7, linewidth=1, marker='^', markersize=3)

# Title and axis labels
ax1.set_title('Time Series of Accident, Assembly, and C-2 Dates by Day\n', fontsize=20, fontweight='bold')
ax1.set_ylabel('Total Accident and Assembly Dates\n', fontweight='bold', fontsize=14)
ax2.set_ylabel('\nTotal C-2 Dates', fontweight='bold', fontsize=14)
ax1.set_xlabel('\nDay', fontweight='bold', fontsize=14)

# Set limits for Y-axis
ax1.set_ylim(0, 1800)
ax2.set_ylim(0, 1800)

# Increase the font size of X and Y axis labels
ax1.tick_params(axis='both', which='major', labelsize=12)
ax2.tick_params(axis='both', which='major', labelsize=12)

# Legend for the time series
legend_lines = [mlines.Line2D([], [], color=palette[0], linestyle='-', alpha=1, marker='s'),
                mlines.Line2D([], [], color=palette[1], linestyle='-', alpha=1, marker='o'),
                mlines.Line2D([], [], color=palette[2], linestyle='-', alpha=1, marker='^')]
legend_labels = ['Accident Dates', 'Assembly Dates', 'C-2 Dates']

ax1.legend(legend_lines, legend_labels, title='', fontsize='12', bbox_to_anchor=(0.42, 1.02), loc='upper left', frameon=False)

# Limit the x to 2020-2023
# plt.xlim(pd.Timestamp('2020-01-01'), pd.Timestamp('2023-1-31'))

# Remove top and right spines for cleaner visualization
sns.despine(top=True, right=False)
plt.tight_layout()
plt.show()

# %%
# 3 Histograms for 'Accident Date', 'Assembly Date', and 'C-2 Date' side-by-side
fig, ax = plt.subplots(1, 3, figsize=(20, 6))

# Plotting 'Accident Date' on ax[0]
sns.histplot(train_data['Accident Date'], kde=True, color=palette[0], ax=ax[0])
ax[0].set_title('Accident Date', fontsize=16, fontweight='bold')
ax[0].set_xlabel('Date', fontsize=12, fontweight='bold')
ax[0].set_ylabel('Frequency', fontsize=12, fontweight='bold')
# ax[0].set_xlim(pd.Timestamp('2020-01-01'), pd.Timestamp('2023-12-31'))

# Plotting 'Assembly Date' on ax[1]
sns.histplot(train_data['Assembly Date'], kde=True, color=palette[1], ax=ax[1])
ax[1].set_title('Assembly Date', fontsize=16, fontweight='bold')
ax[1].set_xlabel('Date', fontsize=12, fontweight='bold')
ax[1].set_ylabel('Frequency', fontsize=12, fontweight='bold')

# Plotting 'C-2 Date' on ax[2]
sns.histplot(train_data['C-2 Date'], kde=True, color=palette[2], ax=ax[2])
ax[2].set_title('C-2 Date', fontsize=16, fontweight='bold')
ax[2].set_xlabel('Date', fontsize=12, fontweight='bold')
ax[2].set_ylabel('Frequency', fontsize=12, fontweight='bold')
# ax[2].set_xlim(pd.Timestamp('2020-01-01'), pd.Timestamp('2023-12-31'))

# Remove top and right spines for cleaner visualization
sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **`Age at Injury`** and **`Birth Year`**

# %%
# Check the distribution of 'Age at Injury' and 'Birth Year'
fig, ax = plt.subplots(1, 2, figsize=(20, 6))

# Plotting 'Age at Injury'
sns.histplot(train_data['Age at Injury'], kde=True, color='#FFB800', ax=ax[0])
ax[0].set_title('Age at Injury', fontsize=16, fontweight='bold')
ax[0].set_xlabel('Age', fontsize=12, fontweight='bold')
ax[0].set_ylabel('Frequency', fontsize=12, fontweight='bold')

# Plotting 'Birth Year'
sns.histplot(train_data['Birth Year'], kde=True, color='#CC9300', ax=ax[1])
ax[1].set_title('Birth Year', fontsize=16, fontweight='bold')
ax[1].set_xlabel('Year', fontsize=12, fontweight='bold')
ax[1].set_ylabel('Frequency', fontsize=12, fontweight='bold')

# Remove top and right spines for cleaner visualization
sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# > **`Age at Injury`** and **`Birth Year`** have similar distributions, as expected. However, there are some anomalies, such as ages of 0 and 117 years old, which need to be checked.

# %%
# Check how many cases have an age of 0 and birth year of 0
print('The number of cases where the age is 0:', train_data[train_data['Age at Injury'] == 0].shape[0], '(', round(train_data[train_data['Age at Injury'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')
print('The number of cases where the birth year is 0:', train_data[train_data['Birth Year'] == 0].shape[0], '(', round(train_data[train_data['Birth Year'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')

# Check how many missing values are in the 'Age at Injury' and 'Birth Year' column
print('The number of missing values in the Age at Injury column:', train_data['Age at Injury'].isnull().sum())
print('The number of missing values in the Birth Year column:', train_data['Birth Year'].isnull().sum())

# %%
# Replace 'Birth Year' of 0 with NaN
train_data['Birth Year'] = train_data['Birth Year'].mask(train_data['Birth Year'] == 0, np.nan)
test_data['Birth Year'] = test_data['Birth Year'].mask(test_data['Birth Year'] == 0, np.nan)

# %%
# Check the cases where the age is 0 and the birth year is complete
train_data[(train_data['Age at Injury'] == 0) & (train_data['Birth Year'].notnull())]
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 370              NaT            0.0                              N
# 396              NaT            0.0                              N
# 599              NaT            0.0                              N
# 760              NaT            0.0                              N
# 1088             NaT            0.0                              N
# ...              ...            ...                            ...
# 592566           NaT            0.0                              N
# 592914           NaT            0.0                              N
# 592978           NaT            0.0                              N
# 593063           NaT            0.0                              N
# 593087    2022-12-13            0.0                              N
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 370       2020-01-02                       Y                  0.0      1959.0
# 396       2020-01-02                       Y                  0.0      1984.0
# 599       2020-01-02                       Y                  0.0      1967.0
# 760       2020-01-03                       Y                  0.0      1971.0
# 1088      2020-01-03                       N                  0.0      1959.0
# ...              ...                     ...                  ...         ...
# 592566    2022-12-29                       Y                  0.0      1967.0
# 592914    2022-12-30                       Y                  0.0      1961.0
# 592978    2022-12-30                       Y                  0.0      1972.0
# 593063    2022-12-30                       Y                  0.0      1957.0
# 593087    2022-12-30                       N                  0.0      1903.0
#
#          C-2 Date    C-3 Date                    Carrier Name  \
# 370           NaT  2019-12-23  STARR INDEMNITY & LIABILITY CO
# 396           NaT  2019-12-27               LM INSURANCE CORP
# 599           NaT  2019-12-27    AMERICAN ZURICH INSURANCE CO
# 760           NaT  2019-12-23      NEW HAMPSHIRE INSURANCE CO
# 1088          NaT  2019-12-27                COUNTY OF NASSAU
# ...           ...         ...                             ...
# 592566        NaT  2022-12-21            STATE INSURANCE FUND
# 592914 2023-01-10  2022-12-27                COUNTY OF NASSAU
# 592978 2023-01-20  2022-12-22               LM INSURANCE CORP
# 593063        NaT  2022-12-27    CNY OTHER THAN ED, HED WATER
# 593087 2022-12-30         NaN  SECURITY NATIONAL INSURANCE CO
#
#            Carrier Type  Claim Identifier Claim Injury Type County of Injury  \
# 370         1A. PRIVATE           5394068       2. NON-COMP            BRONX
# 396         1A. PRIVATE           5393794       2. NON-COMP         ONONDAGA
# 599         1A. PRIVATE           5393999      1. CANCELLED           ALBANY
# 760         1A. PRIVATE           5394824      1. CANCELLED            KINGS
# 1088    3A. SELF PUBLIC           5394616       2. NON-COMP          SUFFOLK
# ...                 ...               ...               ...              ...
# 592566          2A. SIF           6163633      1. CANCELLED           QUEENS
# 592914  3A. SELF PUBLIC           6164216       2. NON-COMP           NASSAU
# 592978      1A. PRIVATE           6164933       2. NON-COMP            KINGS
# 593063  3A. SELF PUBLIC           6164931      1. CANCELLED            KINGS
# 593087      1A. PRIVATE           6164433       2. NON-COMP           ALBANY
#
#        COVID-19 Indicator District Name First Hearing Date Gender  \
# 370                     N           NYC                NaN      M
# 396                     N      SYRACUSE                NaN      F
# 599                     N        ALBANY                NaN      M
# 760                     N           NYC                NaN      M
# 1088                    N     HAUPPAUGE                NaN      F
# ...                   ...           ...                ...    ...
# 592566                  N           NYC                NaN      F
# 592914                  N           NYC         2023-02-17      M
# 592978                  N           NYC                NaN      M
# 593063                  N           NYC                NaN      M
# 593087                  N        ALBANY                NaN      F
#
#         IME-4 Count  Industry Code          Industry Code Description  \
# 370             NaN           23.0                       CONSTRUCTION
# 396             NaN            NaN                                NaN
# 599             NaN            NaN                                NaN
# 760             NaN           32.0                      MANUFACTURING
# 1088            NaN            NaN                                NaN
# ...             ...            ...                                ...
# 592566          NaN            NaN                                NaN
# 592914          NaN           92.0              PUBLIC ADMINISTRATION
# 592978          NaN           23.0                       CONSTRUCTION
# 593063          NaN            NaN                                NaN
# 593087          NaN           62.0  HEALTH CARE AND SOCIAL ASSISTANCE
#
#        Medical Fee Region  OIICS Nature of Injury Description  \
# 370                    IV                                 NaN
# 396                    II                                 NaN
# 599                    II                                 NaN
# 760                    IV                                 NaN
# 1088                   IV                                 NaN
# ...                   ...                                 ...
# 592566                 IV                                 NaN
# 592914                 IV                                 NaN
# 592978                 IV                                 NaN
# 593063                 IV                                 NaN
# 593087                 II                                 NaN
#
#         WCIO Cause of Injury Code WCIO Cause of Injury Description  \
# 370                           NaN                              NaN
# 396                           NaN                              NaN
# 599                           NaN                              NaN
# 760                           NaN                              NaN
# 1088                          NaN                              NaN
# ...                           ...                              ...
# 592566                        NaN                              NaN
# 592914                       52.0                  CONTINUAL NOISE
# 592978                       60.0         STRAIN OR INJURY BY, NOC
# 593063                        NaN                              NaN
# 593087                       17.0   OBJECT BEING LIFTED OR HANDLED
#
#         WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 370                            NaN                               NaN
# 396                            NaN                               NaN
# 599                            NaN                               NaN
# 760                            NaN                               NaN
# 1088                           NaN                               NaN
# ...                            ...                               ...
# 592566                         NaN                               NaN
# 592914                        31.0        HEARING LOSS OR IMPAIRMENT
# 592978                        78.0            CARPAL TUNNEL SYNDROME
# 593063                         NaN                               NaN
# 593087                        43.0                          PUNCTURE
#
#         WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 370                        NaN                           NaN      NaN
# 396                        NaN                           NaN    13212
# 599                        NaN                           NaN    12209
# 760                        NaN                           NaN    11231
# 1088                       NaN                           NaN    11701
# ...                        ...                           ...      ...
# 592566                     NaN                           NaN    11422
# 592914                    13.0                        EAR(S)    11756
# 592978                    39.0           WRIST (S) & HAND(S)    11221
# 593063                     NaN                           NaN    11221
# 593087                    36.0                     FINGER(S)    12309
#
#         Agreement Reached      WCB Decision  Number of Dependents
# 370                   0.0  Not Work Related                   6.0
# 396                   0.0  Not Work Related                   4.0
# 599                   0.0  Not Work Related                   6.0
# 760                   0.0  Not Work Related                   1.0
# 1088                  0.0  Not Work Related                   6.0
# ...                   ...               ...                   ...
# 592566                0.0  Not Work Related                   1.0
# 592914                0.0  Not Work Related                   0.0
# 592978                0.0  Not Work Related                   6.0
# 593063                0.0  Not Work Related                   0.0
# 593087                0.0  Not Work Related                   1.0
#
# [3278 rows x 33 columns]

# %%
# Impute missing values in the Age at Injury column
# Replace 'Age at Injury' values with calculated age only where the age is 0
train_data.loc[train_data['Age at Injury'] == 0, 'Age at Injury'] = train_data['Assembly Date'].dt.year - train_data['Birth Year']
test_data.loc[test_data['Age at Injury'] == 0, 'Age at Injury'] = test_data['Assembly Date'].dt.year - test_data['Birth Year']

# Check if there are still cases where the age is 0
print('The number of cases where the age is 0:', train_data[train_data['Age at Injury'] == 0].shape[0], '(', round(train_data[train_data['Age at Injury'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')
# Out:
# The number of cases where the age is 0: 0 ( 0.0 %)

# %%
# Check the distribution of 'Age at Injury' and 'Birth Year' after the imputation
fig, ax = plt.subplots(1, 2, figsize=(20, 6))

# Plotting 'Age at Injury'
sns.histplot(train_data['Age at Injury'], kde=True, color='#FFB800', ax=ax[0])
ax[0].set_title('Age at Injury', fontsize=16, fontweight='bold')
ax[0].set_xlabel('Age', fontsize=12, fontweight='bold')
ax[0].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    
# Plotting 'Birth Year'
sns.histplot(train_data['Birth Year'], kde=True, color='#CC9300', ax=ax[1])
ax[1].set_title('Birth Year', fontsize=16, fontweight='bold')
ax[1].set_xlabel('Year', fontsize=12, fontweight='bold')
ax[1].set_ylabel('Frequency', fontsize=12, fontweight='bold')

sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# > The distribution of **`Age at Injury`** and **`Birth Year`** seems more consistent after the imputation.
#
# - As expected, the distribution of ages and year of birth have opposite relationships $\rightarrow$ the higher the **`Age at Injury`** - , the lower the **`Birth Year`**.

# %%
# Check how many cases have an age of 0 and birth year of 0
print('The number of cases where the age is 0:', train_data[train_data['Age at Injury'] == 0].shape[0], '(', round(train_data[train_data['Age at Injury'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')
print('The number of cases where the birth year is 0:', train_data[train_data['Birth Year'] == 0].shape[0], '(', round(train_data[train_data['Birth Year'] == 0].shape[0] / train_data.shape[0] * 100, 2), '%)')

# Check how many missing values are in the 'Age at Injury' and 'Birth Year' column
print('The number of missing values in the Age at Injury column:', train_data['Age at Injury'].isnull().sum(), '(', round(train_data['Age at Injury'].isnull().sum() / train_data.shape[0] * 100, 2), '%)')
print('The number of missing values in the Birth Year column:', train_data['Birth Year'].isnull().sum(), '(', round(train_data['Birth Year'].isnull().sum() / train_data.shape[0] * 100, 2), '%)')
# Out:
# The number of cases where the age is 0: 0 ( 0.0 %)
# The number of cases where the birth year is 0: 0 ( 0.0 %)
# The number of missing values in the Age at Injury column: 21631 ( 3.64 %)
# The number of missing values in the Birth Year column: 73604 ( 12.4 %)

# %% [markdown]
# > The number of cases where the age is 0 and the birth year is complete is 0, which means that the imputation was successful and just increased $XX\%$ of the missing values in the **`Age at Injury`** column and $XX\%$ **`Birth Year`** column.
#
# > Both columns have same information so we can use just one of them for the model.

# %% [markdown]
# ---

# %% [markdown]
# ### **`Gender`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Alternative Dispute Resolution`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Attorney/Representative`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Average Weekly Wage`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Carrier Type`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Claim Injury Type`**

# %% [markdown]
# ### **`COVID-19 Indicator`**

# %% [markdown]
# ### **`County of Injury`**

# %% [markdown]
# ### **`District Name`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Industry Code Description`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Medical Fee Region`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`WCIO Cause of Injury Code`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`WCIO Nature of Injury Code`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`WCIO Part Of Body Code`**

# %% [markdown]
# ---

# %% [markdown]
# ### **`Zip Code`**

# %% [markdown]
# ---

# %% [markdown]
# ## 🛠️ Data Cleaning and Preparation

# %% [markdown]
# ---

# %% [markdown]
# ## 🔗 Correlation / Association between Variables

# %% [markdown]
# ---

# %% [markdown]
# # 💡 Modeling

# %% [markdown]
# ### ⚖️ Training/Testing Division

# %% [markdown]
# ---

# %% [markdown]
# ### 🧪 Model Selection

# %% [markdown]
# ---

# %% [markdown]
# ### 📏 Model Evaluation

# %% [markdown]
# ---

# %% [markdown]
# ### 📈 Model Optimization

# %% [markdown]
# ---

# %% [markdown]
# ### 📊 Feature Importance

# %% [markdown]
# ---

# %% [markdown]
# ## 🔮 Test Data Prediction

# %% [markdown]
# ---

# %% [markdown]
# ## 📋 CSV Export - Submission

# %%
# Each submission in Kaggle should have different names and should have the version name in the following format 
# – GroupXX_VersionXX.csv (for example, Group 1 submitted his 8th version, the file should be named Group01__Version08.csv)


# final_data.to_csv('submissions/Group33_Version01.csv', index=False)
